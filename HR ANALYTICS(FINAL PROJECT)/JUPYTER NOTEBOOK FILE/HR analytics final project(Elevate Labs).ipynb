# %%
Python Code to Load and Explore the Data

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Optional: Display plots inline
# %matplotlib inline

# %%
# Step 2: Load the dataset
file_path = r"C:\Users\LENOVO\Desktop\Elevate Labs Internship tasks\Final Project\employee_attrition_dataset_10000.csv"
df = pd.read_csv(file_path)

# %%
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (10000, 26)
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58    Male         Single    Finance    Manager          5
# 1            2   48  Female       Divorced         HR  Assistant          4
# 2            3   34  Female        Married  Marketing    Manager          4
# 3            4   27  Female       Divorced         HR    Manager          4
# 4            5   40    Male        Married         HR    Analyst          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0            7332           81                24  ...        No
# 1            6069           55                18  ...       Yes
# 2           11485           65                 6  ...       Yes
# 3           18707           28                12  ...        No
# 4           16398           92                 3  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
# Import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Convert 'Attrition' column to binary (Yes=1, No=0)
df['Attrition_Flag'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
# Group by Department and calculate mean attrition rate
dept_attrition = df.groupby('Department')['Attrition_Flag'].mean().sort_values(ascending=False)

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=dept_attrition.values, y=dept_attrition.index, palette="coolwarm")
plt.title("Department-wise Attrition Rate", fontsize=16)
plt.xlabel("Attrition Rate")
plt.ylabel("Department")
plt.grid(axis='x')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11720\3088674617.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dept_attrition.values, y=dept_attrition.index, palette="coolwarm")

# %%
# Create salary bands using quantile-based binning
df['Salary_Band'] = pd.qcut(df['Monthly_Income'], q=5)

# %%
# Calculate attrition rate per salary band
salary_attrition = df.groupby('Salary_Band')['Attrition_Flag'].mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11720\2566449727.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   salary_attrition = df.groupby('Salary_Band')['Attrition_Flag'].mean()

# %%
# Plot
plt.figure(figsize=(10, 6))
salary_attrition.plot(kind='bar', color='orange', edgecolor='black')
plt.title("Salary Band-wise Attrition Rate", fontsize=16)
plt.xlabel("Salary Band (Monthly Income)")
plt.ylabel("Attrition Rate")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Group and calculate attrition rate by 'Years_Since_Last_Promotion'
promo_attrition = df.groupby('Years_Since_Last_Promotion')['Attrition_Flag'].mean()

# %%
plt.figure(figsize=(10, 6))
promo_attrition.plot(kind='line', marker='o', color='green')
plt.title("Attrition vs Years Since Last Promotion", fontsize=16)
plt.xlabel("Years Since Last Promotion")
plt.ylabel("Attrition Rate")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset

# %%
df = pd.read_csv("C:/Users/LENOVO/Desktop/Elevate Labs Internship tasks/Final Project/employee_attrition_dataset_10000.csv")

# %%
# Convert Attrition to binary

# %%
df["Attrition_Flag"] = df["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
# --- 1. Department-wise Attrition ---

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Department', y='Attrition_Flag', estimator='mean', palette='Reds')
plt.title("Attrition Rate by Department")
plt.ylabel("Attrition Rate")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\197454966.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Department', y='Attrition_Flag', estimator='mean', palette='Reds')

# %%
print(df.columns.tolist())
# Out:
# ['Employee_ID', 'Age', 'Gender', 'Marital_Status', 'Department', 'Job_Role', 'Job_Level', 'Monthly_Income', 'Hourly_Rate', 'Years_at_Company', 'Years_in_Current_Role', 'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction', 'Performance_Rating', 'Training_Hours_Last_Year', 'Overtime', 'Project_Count', 'Average_Hours_Worked_Per_Week', 'Absenteeism', 'Work_Environment_Satisfaction', 'Relationship_with_Manager', 'Job_Involvement', 'Distance_From_Home', 'Number_of_Companies_Worked', 'Attrition', 'Attrition_Flag']

# %%
# --- 2. Salary Band-wise Attrition ---
# Create salary bands

# %%
df["Salary_Band"] = pd.qcut(df["Monthly_Income"], q=4, labels=["Low", "Medium", "High", "Very High"])
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Salary_Band", y="Attrition_Flag", estimator='mean', palette='Blues')
plt.title("Attrition Rate by Salary Band")
plt.ylabel("Attrition Rate")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\340888364.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Salary_Band", y="Attrition_Flag", estimator='mean', palette='Blues')

# %%
# --- 3. Years Since Last Promotion ---

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Years_Since_Last_Promotion", y="Attrition_Flag")
plt.title("Attrition Rate vs. Years Since Last Promotion")
plt.ylabel("Attrition Rate")
plt.show()

# %%
# --- 4. Age Group Attrition ---

# %%
df["Age_Group"] = pd.cut(df["Age"], bins=[0, 25, 35, 45, 55, 100], labels=["<25", "25-35", "36-45", "46-55", "55+"])
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Age_Group", y="Attrition_Flag", palette="coolwarm")
plt.title("Attrition by Age Group")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\296841360.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Age_Group", y="Attrition_Flag", palette="coolwarm")

# %%
# --- 5. Job Role Attrition ---

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Job_Role", y="Attrition_Flag", estimator='mean')
plt.title("Attrition by Job Role")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- 6. Overtime and Attrition ---

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=df, x="Overtime", y="Attrition_Flag", palette="Set2")
plt.title("Attrition by Overtime Status")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\1539268148.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Overtime", y="Attrition_Flag", palette="Set2")

# %%
# --- 7. Work-Life Balance vs. Attrition ---

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=df, x="Work_Life_Balance", y="Attrition_Flag", palette="Purples")
plt.title("Attrition vs. Work-Life Balance")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\2944752555.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Work_Life_Balance", y="Attrition_Flag", palette="Purples")

# %%
# --- 8. Years at Company vs Attrition ---

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Years_at_Company", y="Attrition_Flag")
plt.title("Attrition vs. Years at Company")
plt.ylabel("Attrition Rate")
plt.show()

# %%
# --- 9. Monthly Income vs. Attrition (Scatter) ---

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Monthly_Income", y="Attrition_Flag", alpha=0.4)
plt.title("Attrition vs. Monthly Income")
plt.show()

# %%
🔟. Attrition by Job Level

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Job_Level", y="Attrition_Flag", palette="Oranges")
plt.title("Attrition Rate by Job Level")
plt.ylabel("Attrition Rate")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\703360969.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Job_Level", y="Attrition_Flag", palette="Oranges")

# %%
11. Attrition by Marital Status

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=df, x="Marital_Status", y="Attrition_Flag", palette="Greens")
plt.title("Attrition by Marital Status")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\290951616.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Marital_Status", y="Attrition_Flag", palette="Greens")

# %%
12. Attrition by Training Hours

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Training_Hours_Last_Year", y="Attrition_Flag")
plt.title("Attrition vs. Training Hours Last Year")
plt.ylabel("Attrition Rate")
plt.show()

# %%
13. Attrition by Distance from Home

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Distance_From_Home", y="Attrition_Flag")
plt.title("Attrition vs. Distance from Home")
plt.ylabel("Attrition Rate")
plt.show()

# %%
 14. Attrition by Gender

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=df, x="Gender", y="Attrition_Flag", palette="pastel")
plt.title("Attrition by Gender")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\4250433730.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Gender", y="Attrition_Flag", palette="pastel")

# %%
 15. Attrition by Relationship with Manager

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Relationship_with_Manager", y="Attrition_Flag", palette="YlGnBu")
plt.title("Attrition vs. Relationship with Manager (1-4)")
plt.ylabel("Attrition Rate")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\2544702455.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Relationship_with_Manager", y="Attrition_Flag", palette="YlGnBu")

# %%
16. Attrition by Job Involvement

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Job_Involvement", y="Attrition_Flag", palette="Purples")
plt.title("Attrition by Job Involvement")
plt.ylabel("Attrition Rate")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10236\1122580632.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Job_Involvement", y="Attrition_Flag", palette="Purples")

# %%
THANK YOU BY DURGAM MANOHAR
